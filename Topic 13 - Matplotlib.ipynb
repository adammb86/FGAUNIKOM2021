# %% [markdown]
# # Matplotlib
#
# Matplotlib adalah salah satu library di Python yang digunakan untuk memvisualisasikan data dalam bentuk grafik atau diagram. Visualisasi data tentunya mempermudah pembaca data dalam melakukan pemahaman data. Sama dengan beberapa library sebelumnya, kita harus menginstal terelbih dahulu library ini sebelum dapat menggunakannya. Untuk melakukan instalasi library matplotlib, silakan gunakan perintah berikut:
#
# ```python
# pip3 install matplotlib
# ```
#
# atau untuk pengguna Anaconda dapat menggunakan perintah:
#
# ```python
# conda install matplotlib
# ```

# %%
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/anaconda3/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/anaconda3/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: six in /usr/local/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
# !conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import matplotlib.pyplot as plt

dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '_IoffContext',
#  '_IonContext',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_code_objs',
#  '_copy_docstring_and_deprecators',
#  '_get_required_interactive_framework',
#  '_interactive_bk',
#  '_log',
#  '_pylab_helpers',
#  '_setup_pyplot_info_docstrings',
#  '_warn_if_gui_out_of_main_thread',
#  '_xkcd',
#  'acorr',
#  'angle_spectrum',
#  'annotate',
#  'arrow',
#  'autoscale',
#  'autumn',
#  'axes',
#  'axhline',
#  'axhspan',
#  'axis',
#  'axline',
#  'axvline',
#  'axvspan',
#  'bar',
#  'bar_label',
#  'barbs',
#  'barh',
#  'bone',
#  'box',
#  'boxplot',
#  'broken_barh',
#  'cbook',
#  'cla',
#  'clabel',
#  'clf',
#  'clim',
#  'close',
#  'cm',
#  'cohere',
#  'colorbar',
#  'colormaps',
#  'connect',
#  'contour',
#  'contourf',
#  'cool',
#  'copper',
#  'csd',
#  'cycler',
#  'delaxes',
#  'disconnect',
#  'docstring',
#  'draw',
#  'draw_all',
#  'draw_if_interactive',
#  'errorbar',
#  'eventplot',
#  'figaspect',
#  'figimage',
#  'figlegend',
#  'fignum_exists',
#  'figtext',
#  'figure',
#  'fill',
#  'fill_between',
#  'fill_betweenx',
#  'findobj',
#  'flag',
#  'functools',
#  'gca',
#  'gcf',
#  'gci',
#  'get',
#  'get_backend',
#  'get_cmap',
#  'get_current_fig_manager',
#  'get_figlabels',
#  'get_fignums',
#  'get_plot_commands',
#  'get_scale_names',
#  'getp',
#  'ginput',
#  'gray',
#  'grid',
#  'hexbin',
#  'hist',
#  'hist2d',
#  'hlines',
#  'hot',
#  'hsv',
#  'importlib',
#  'imread',
#  'imsave',
#  'imshow',
#  'inferno',
#  'inspect',
#  'install_repl_displayhook',
#  'interactive',
#  'ioff',
#  'ion',
#  'isinteractive',
#  'jet',
#  'legend',
#  'locator_params',
#  'logging',
#  'loglog',
#  'magma',
#  'magnitude_spectrum',
#  'margins',
#  'matplotlib',
#  'matshow',
#  'minorticks_off',
#  'minorticks_on',
#  'mlab',
#  'new_figure_manager',
#  'nipy_spectral',
#  'np',
#  'pause',
#  'pcolor',
#  'pcolormesh',
#  'phase_spectrum',
#  'pie',
#  'pink',
#  'plasma',
#  'plot',
#  'plot_date',
#  'plotting',
#  'polar',
#  'prism',
#  'psd',
#  'quiver',
#  'quiverkey',
#  'rc',
#  'rcParams',
#  'rcParamsDefault',
#  'rcParamsOrig',
#  'rc_context',
#  'rcdefaults',
#  'rcsetup',
#  're',
#  'register_cmap',
#  'rgrids',
#  'savefig',
#  'sca',
#  'scatter',
#  'sci',
#  'semilogx',
#  'semilogy',
#  'set_cmap',
#  'set_loglevel',
#  'setp',
#  'show',
#  'specgram',
#  'spring',
#  'spy',
#  'stackplot',
#  'stairs',
#  'stem',
#  'step',
#  'streamplot',
#  'style',
#  'subplot',
#  'subplot2grid',
#  'subplot_mosaic',
#  'subplot_tool',
#  'subplots',
#  'subplots_adjust',
#  'summer',
#  'suptitle',
#  'switch_backend',
#  'sys',
#  'table',
#  'text',
#  'thetagrids',
#  'threading',
#  'tick_params',
#  'ticklabel_format',
#  'tight_layout',
#  'time',
#  'title',
#  'tricontour',
#  'tricontourf',
#  'tripcolor',
#  'triplot',
#  'twinx',
#  'twiny',
#  'uninstall_repl_displayhook',
#  'violinplot',
#  'viridis',
#  'vlines',
#  'waitforbuttonpress',
#  'winter',
#  'xcorr',
#  'xkcd',
#  'xlabel',
#  'xlim',
#  'xscale',
#  'xticks',
#  'ylabel',
#  'ylim',
#  'yscale',
#  'yticks']

# %% [markdown]
# Dokumentasi lengkap perihal matplotlib dapat diakses melalui https://matplotlib.org/. Jenis grafik atau diagram yang didukung oleh matplotlib dapat dilihat di https://matplotlib.org/stable/gallery/index.html. Matplotlib mendukung visualisasi dua dan tiga dimensi.
#
# Untuk bisa melihat hasil visualisasi dari matplotlib di Jupyter Notebook, jalankan kode program berikut:

# %%
# %matplotlib inline

# %% [markdown]
# ><b>Catatan:</b> Kode program itu hanya dibutuhkan ketika kita menjalankan matplotlib di Jupyter Notebook. Apabila menjalankan matplotlib di editor lain, silakan gunakan fungsi ``show()`` di bagian paling akhir dari plotting command agar visualisasi muncul secara pop-up di jendela yang lain.
#
# Topik ini akan membahas:
#
# 1. Visualisasi Numpy Array
# 2. Method di matplotlib

# %% [markdown]
# # Matplotlib untuk Numpy Array
#
# Salah satu struktur data yang didukung oleh matplotlib adalah numpy array (ndarray). Untuk bisa memvisualisasikan diagram dari numpy array, gunakan perintah berikut:
#
# ```python
# plot(numpy_array1, numpy_array2, '<nilaiwarna>')
# ```
#
# Mari kita coba kode program berikut:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11) # spaced number di numpy array, baca topik 9
y = x ** 2

# %%
print(x)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]

# %%
print(y)
# Out:
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x, y, 'r') # 'r' adalah nilai warna merah
plt.xlabel('Judul sumbu X di sini')
plt.ylabel('Judul sumbu y di sini')
plt.title('Judul Diagram di sini')
plt.show()

# %% [markdown]
# ><b>Catatan:</b> Untuk melihat nilai warna di matplotlib, silakan kunjungi https://matplotlib.org/stable/gallery/color/named_colors.html.

# %% [markdown]
# # Multiplot di canvas yang sama
#
# Diagram atau grafik dari matplotlib akan ditampilkan dalam sebuah komponen canvas. Seperti yang kita coba sebelumnya, satu canvas bisa menampilkan satu grafik. Bagaimana kalau kita ingin menampilkan lebih dari satu grafik dalam satu buah canvas? Kita bisa menggunakan perintah ``subplot()`` dengan format sebagai berikut:
#
# ```python
# plt.subplot(jumlah_baris, jumlah_kolom, plot_number)
# ```
#
# Mari kita coba kode program berikut ini:

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# # Method dari Matplotlib
#
# Matplotlib merupakan sebuah class yang di dalamnya terdapat banyak method untuk mendukung proses visualisasi. Berikut adalah beberapa method yang sering digunakan pada matplotlib:
#
# | Method | Kegunaan |
# | :--- | :--- |
# | figure() | Membuat canvas kosong |
# | add_axes() | Menambahkan axes (satu set diagram sumbu) pada canvas |
# | subplots() | Automatic axis manager (mirip seperti figure() tapi memiliki automasi dalam membuat axes) |
# | tight_layout() | Men-adjust tampilan axes agar tidak saling tumpang tindih (overlapping) |
# | savefig() | Men-generate output berkualitas tinggi dalam format PNG, JPG, EPS, SVG, PGF and PDF |
# | set_title() | Memberikan judul pada diagram yang ditampilkan |
# | legend() | Memunculkan legenda pada diagram yang ditampilkan |
# | set_xlabel() | Memberikan label pada axis x |
# | set_ylabel() | Memberikan label pada axis y |

# %% [markdown]
# ## Penggunaan Methof Figure dan add_axes
#
# Berikut adalah contoh dari penggunaan method ``figure()`` dan ``add_axes()``:

# %%
fig = plt.figure()

# Menambah axes ke dalam canvas
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plotting array x dan y ke dalam axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %% [markdown]
# Kita juga bisa memunculkan multiaxes seperti pada kode program berikut:

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ## Penggunaan subplots
#
# Berikut contoh penggunaan ``subplots()``:

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# Jika menggunakan ``subplots()`` maka axes akan di-generate otomatis. Kita juga bisa menentukan jumlah kolom dan baris jika ingin menampilkan multiplot. Mari kita coba kode program berikut:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# Penjelasan:
#
# 1. Kode program tersebut memunculkan dua axes dalam dua kolom dan satu baris sesuai dengan isian paramater.
# 2. Hasil dari ``subplots()`` adalah tuple. Oleh karena itu kita menggunakan dua variabel untuk menampung return value dari fungsi tersebut.
#
# Variabel ``axes`` digunakan untuk menampung array axes yang dibentuk dari ``subplots``. Berikut adalah isi dari axes:

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# Dikarenakan axes adalah sebuah numpy array, maka kita bisa melakukan iterasi menggunakan iterator dalam melakukan plotting pada masing-masing axes. Berikut contoh kode programnya:

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# Menampilkan objek figure
fig

# %% [markdown]
# ## Penggunaan tight_layout
#
# Masalah yang umum terjadi di matplotlib ketika multiplot adalah adanya objek yang tumpang tindih di dalam canvas atau disebut juga sebagai <b>Overlapping</b>. Untuk menghindari hal tersebut kita bisa menggunakan fungsi ``tight_layout()`` pada figure atau plot. Berikut contoh penggunaanya:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

fig
plt.tight_layout()

# %% [markdown]
# # Ukuran Figure, Aspect Ratio, dan DPI
#
# Matplotlib menyediakan fasilitas untuk kita menentukan aspect ratio, DPIm dan ukuran figure ketika object figure dibuat (menggunakan method ``figure()``).
#
# Penjelasan:
#
# 1. ``figsize`` berbentuk tuple yang berisikan width dan height dari sebuah figure dalam satuan inchi.
# 2. ``dpi`` singkatan dari dots-per-inch (jumlah pixel dalam setiap inchi). Makin tinggi dpi makin bagus kualitas tampilan grafiknya.
#
# Berikut cara penggunaan parameter-parameter tersebut dalam method ``figure()``:

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %% [markdown]
# Parameter tersebut juga bisa digunakan pada fungsi ``subplots()``. Berikut contoh penggunaannya:

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# # Menyimpan Hasil Visualisasi
#
# Hasil visualisasi dapat disimpan dalam bentuk file berkualitas tinggi dengan format yang sudah disebutkan sebelumnya. Berikut contoh kasusnya:

# %%
fig.savefig("gambar1.png")

# %% [markdown]
# Berikut hasil keluarannya (file akan di-generate ke dalam folder yang sama dengan project Jupyter Notebook):
#
# ![Hasil gambar1,png](https://drive.google.com/uc?export=view&id=1f6O9CCmmgYeHVzcxTWD3VtfBgyDirVno)

# %% [markdown]
# Kita juga bisa mengatur DPI pada hasil keluarannya dengan cara berikut:

# %%
fig.savefig("gambar1.png", dpi=300)

# %% [markdown]
# # Label, dan Titles
#
# Setiap axes mempunyai beberapa komponen yang bisa dikustom, yaitu label, dan titles. Kedua komponen ini bisa digunakan untuk meningkatkan readibility dari visualisasi data yang ditampilkan. Berikut contoh penggunaan kedua komponen tersebut:

# %%
tahun = ['2017', '2018', '2019', '2020', '2021']
jumlah_komoditi = [100, 200, 300, 300, 500]

plt.plot(tahun, jumlah_komoditi, 'b') # 'r' adalah nilai warna merah
plt.xlabel('Tahun')
plt.ylabel('Jumlah Komoditi')
plt.title('Jumlah Komoditi Beras di Indonesia dalam satuan Juta Ton')
plt.show()

# %% [markdown]
# # Legend
#
# Untuk bisa menggunakan legend pada suatu visualisasi, kita bisa menggunakan parameter ``label = '<label_text>'`` pada saat melakukan plot atau di objek yang ditambahkan ke figure. Setelah itu panggil method ``legend()`` untuk memunculkan legend dari visualisasi tersebut. Berikut contoh penggunaannya:

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()

# %% [markdown]
# Apabila legend overlapping dengan objek lainnya maka kita bisa memberikan parameter ``loc = <0..4>`` untuk menentukan posisi kemunculan legend pada figure. Penjelasan nilai ``loc`` dapat dilihat pada tabel berikut:
#
# | Nilai loc | Keterangan |
# | :--- | :--- |
# | 1 | Pojok kanan atas |
# | 2 | Pojok kiri atas |
# | 3 | Pojok kiri bawah |
# | 4 | Pojok kanan bawah |
# | 0 | Matplotlib akan memilihkan posisi optimal untuk menempatkan label |

# %% [markdown]
# # Mengatur Warna, Linewidth, dan Jenis Garis
#
# Kita bisa memilih warna, linewidth, dan jenis garis yang digunakan untuk mem-plotting data. Proses penentuan ini menggunakan konsep yang sama dengan konsep pada Matlab. Ketiga nilai untuk menentukan komponen tersebut diletakkan sebagai paramater pada fungsi ``plot()``. Urutannya adalah:
#
# ```python
# '<nilai_warna><linewidth><jenis_garis>
# ```
#
# Berikut contoh penggunaannya:

# %%
fig, axes = plt.subplots()
axes.plot(x, x**2, 'b.-') # blue line with dots
axes.plot(x, x**3, 'g--') # green dashed line

# %% [markdown]
# Selain menggunakan konsep matlab dalam menentukan tiga komponen tersebut, kita bisa menggunakan mekanisme lain yaitu dengan cara memanggil keyword argument yang sesuai dengan paramter yang mau diubah. Berikut pembahasannya.

# %% [markdown]
# ## Parameter color
#
# Kita bisa menggunakan parameter color untuk menentukan warna dari suatu komponen visualisasi. Selain dengan menyebutkan nama dari warna yang mau digunakan, kita juga bisa menyebutkan warna menggunakan nilai hexa dari warna tersebut. Berikut adalah contoh penggunaannya:

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %% [markdown]
# ## Parameter linewidth dan linestyle
#
# Untuk mengubah linewidth dan linestyle kita bisa menambahkan keyword argument berupa:
#
# | Parameter | Keterangan |
# | :--- | :--- |
# | ``linewidth = `` atau ``lw = `` | linewidth |
# | ``linestyle = `` atau ``ls = `` |  linestyle (nilainya berkisar antara ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’) |
# | ``marker = `` | Memberikan market pada point data (nilainya berkisar antara ``'+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...``) |
# | ``markersize = `` | Menentukan besar dari marker |
# | ``markerfacecolor = `` | Menentukan warna dari marker |
# | ``markeredgewidth = `` | Menentukan lebar dari border marker |
# | ``markeredgecolor = `` | Menentukan warana border dari marker |
#
# Berikut contoh penggunaannya:

# %%
ig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘.’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# # Plot Range
#
# Kita bisa mengatur range dari sebuah axes menggunakan fungsi ``set_ylim()`` untuk sumbu y dan ``set_xlim()`` untuk sumbu x. Kita juga bisa menggunakan ``axis('tight')`` agar matplotlib bisa menyesuaikan range pada axes sesuai data. Berikut contoh penggunaannya:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# # Skala Logaritma
#
# Kita bisa menggunakan skala logaritma untuk mengkustom range pada sumbu x maupun y. Cara penggunaannya adalah dengan memanggil fungsi ``set_yscale('log')`` atau ``set_xscale('log')`` tergantung sumbu apa yang mau disesuaikan. Berikut contoh penggunaannya:

# %%
ig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)");

# %% [markdown]
# # Mengubah Label tick
#
# Kita bisa melakukan perubahan tick (label pada data suatu sumbu/axis) di matplotlib. Fungsi yang digunakan adalah ``set_xticks()`` atau ``set_yticks()``. Selain itu kita juga bisa menggunakan fungsi ``set_yticklabels`` atau ``set_xticklabels`` untuk mmbuat list dari label custom dari setiap tick. Berikut contoh penggunaannya:

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(x, x**2, x, x**3, lw=2)

ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18); # use LaTeX formatted labels

# %% [markdown]
# Dokumentasi yang lengkap tentang modifikasi tick dapat dilihat pada https://matplotlib.org/stable/api/ticker_api.html.

# %% [markdown]
# # Notasi Scientific
#
# Apabila range data pada suatu sumbu besar maka kita bisa menggunakan notasi scientific. Berikut contoh penggunaannya:

# %%
fig, ax = plt.subplots(1, 1)
      
ax.plot(x, x**2, x, np.exp(x))
ax.set_title("scientific notation")

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# # Axis Grid
#
# Kita memberikan grid pada axis di diagram untuk mempermudah pembacaan data. Berikut cara penggunaannya:

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3))

# default grid appearance
axes[0].plot(x, x**2, x, x**3, lw=2)
axes[0].grid(True)

# custom grid appearance
axes[1].plot(x, x**2, x, x**3, lw=2)
axes[1].grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)

# %% [markdown]
# # Custom Axis Spines
#
# Selain memberikan warna pada garis data, kita juga bisa memberikan custom warna maupun properties pada sebuah garis axis (Axis Spines). Berikut contohnya:

# %%
fig, axes = plt.subplots(figsize=(6,2))

axes.spines['bottom'].set_color('blue')
axes.spines['top'].set_color('blue')

axes.spines['left'].set_color('red')
axes.spines['left'].set_linewidth(2)

# turn off axis spine to the right
axes.spines['right'].set_color("none")
axes.yaxis.tick_left() # only ticks on the left side

# %% [markdown]
# # Twin Axis
#
# Terkadang untuk mempermudah pembacaan data, kita memerlukan duplikasi axis spine untuk di bagian atas dan kanan. Mekanisme ini dikenal sebagai <b>Twin Axis</b>. Berikut cara membuat twin axis pada matplotlib:

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, x**2, lw=2, color="blue")
ax1.set_ylabel(r"area $(m^2)$", fontsize=18, color="blue")
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1.twinx()
ax2.plot(x, x**3, lw=2, color="red")
ax2.set_ylabel(r"volume $(m^3)$", fontsize=18, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")

# %% [markdown]
# # Text Annotation
#
# Kita bisa memberikan text annotation untuk memperjelas suatu hal pada diagram. Berikut contoh penggunaannya:

# %%
fig, axes = plt.subplots()

axes.plot(x, x**2, x, x**3)

axes.text(4, 6, r"$y=x^2$", fontsize=20, color="blue")
axes.text(4, 80, r"$y=x^3$", fontsize=20, color="green");
